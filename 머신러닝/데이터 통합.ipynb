# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("car_info.csv",encoding="EUC-KR")
# Out:
# C:\Users\SMHRD\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (32,34,42,46,58,60,62,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_sp=data_kia[data_kia['모델'].str.contains('스포티지')]
data_ss=data_kia[data_kia['모델'].str.contains('쏘렌토')]
data_ray=data_kia[data_kia['모델'].str.contains('레이')]
data_mo=data_kia[data_kia['모델'].str.contains('모닝')]
data_k3=data_kia[data_kia['모델'].str.contains('K3')]
data_k5=data_kia[data_kia['모델'].str.contains('K5')]
data_k7=data_kia[data_kia['모델'].str.contains('K7')]
data_k9=data_kia[data_kia['모델'].str.contains('K9')]
data_total = pd.concat([data_sp,data_ss,data_ray,data_mo,data_k3,data_k5,data_k7,data_k9])
data_total
# Out:
#      제조사         모델        세부모델     등급    연식    출시일     차량가격 차종국가    복합연비  \
# 4044  기아  스포티지 더 볼드  1.6 디젤 2WD    럭셔리  2019  18.09  2,366만원   한국  16km/ℓ
# 4045  기아  스포티지 더 볼드  1.6 디젤 2WD  프레스티지  2019  18.09  2,548만원   한국  16km/ℓ
# 4046  기아  스포티지 더 볼드  1.6 디젤 2WD   노블레스  2019  18.09  2,739만원   한국  15km/ℓ
# 4047  기아  스포티지 더 볼드  1.6 디젤 2WD  인텔리전트  2019  18.09  2,989만원   한국  15km/ℓ
# 4048  기아  스포티지 더 볼드  1.6 디젤 4WD    럭셔리  2019  70.01  2,572만원   한국  15km/ℓ
# ...   ..        ...         ...    ...   ...    ...      ...  ...     ...
# 3579  기아         K9     3.8 GDI  프레지던트  2012  12.05  8,640만원   한국   9km/ℓ
# 3580  기아         K9     3.8 GDI  프레지던트  2013  13.01  8,538만원   한국   9km/ℓ
# 3581  기아         K9     3.8 GDI    VIP  2014  14.01  6,830만원   한국   9km/ℓ
# 3582  기아         K9     3.8 GDI   RVIP  2013  13.01  7,580만원   한국   9km/ℓ
# 3583  기아         K9     3.8 GDI   RVIP  2014  14.01  7,830만원   한국   9km/ℓ
#
#           배기량   최고출력    최대토크             에어백  \
# ...

# %%
del data_total['승차정원']
del data_total['공차중량(kg)']
del data_total['파워트레인']
del data_total['기본']
del data_total['CO2배출(g/km)']
del data_total['최소회전반경(ft)']
del data_total['최저지상고(mm)']
del data_total['측간거리(mm)']
del data_total['윤거(전x후mm)']
del data_total['차체(길이x너비x높이mm)']
del data_total['스티어링']
del data_total['서스펜션(전/후)']
del data_total['브레이크(전/후)']
del data_total['최고속도(km/h)']
del data_total['0→100km/h(초)']
del data_total['실린더수']
del data_total['엔진형식']
del data_total['기타.4']
del data_total['단자']
del data_total['블루투스']
del data_total['스피커']
del data_total['기타.3']
del data_total['스타트스톱']
del data_total['헤드업 디스플레이']
del data_total['전자식파킹브레이크']
del data_total['크루즈컨트롤']
del data_total['주차보조시스템']
del data_total['스티어링휠']
del data_total['에어컨']
del data_total['기타.2']
del data_total['룸미러']
del data_total['뒷좌석']
del data_total['동승석']
del data_total['운전석']
del data_total['시트재질']
del data_total['시트배열']
del data_total['기타.1']
del data_total['사이드미러']
del data_total['리어램프']
del data_total['기타']
del data_total['주행안전']
del data_total['최고출력(ps/rpm)']
del data_total['최대토크(kg·m/rpm)']
del data_total['차종국가']
del data_total['출시일']
del data_total['연료탱크(ℓ)']
del data_total['적재용량(kg)']
del data_total['복합연비']

# %%
data_total['차량가격']=data_total['차량가격'].str.replace("만원","").str.replace(",","")
data_total['차량가격']=data_total['차량가격'].astype("float64")

# %%
data_total['배기량']=data_total['배기량'].str.replace("cc","").str.replace(",","")
data_total['배기량']=data_total['배기량'].astype("float64")

# %%
data_total['최고출력']=data_total['최고출력'].str.replace("ps","")

# %%
data_total['세부모델']=data_total['세부모델'].apply(lambda x: x.upper())

# %%
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)
# Out:
# pandas version:  1.1.3

# %%
data_kia=data[data['제조사']=='현대']

# %%
data_j=data[data['제조사']=='제네시스']

# %%
data_rs=data[data['제조사']=='르노삼성']

# %%
data_car_1=pd.concat([data_kia,data_j,data_rs])

# %%
data_car_1.to_csv('car_info_1.csv',encoding='EUC-KR',index=False)

# %%
data_kia=data[data['제조사']=='기아']

# %%
data_j=data[data['제조사']=='쉐보레/대우']

# %%
data_j=data[data['제조사']=='쌍용']

# %%
data_car_2=pd.concat([data_kia,data_j,data_rs])

# %%
data_car_2.to_csv('car_info_2.csv',encoding='EUC-KR',index=False)

# %%
data_car_2=pd.read_csv('car_info_2.csv',encoding='EUC-KR')

# %%
data_korando=data_car_2[(data_car_2["모델"]).str.contains("코란도")] 
data_korando.to_csv('car_코란도.csv',encoding='EUC-KR',index=False)

# %%
data_k3=data_car_2[(data_car_2["모델"]).str.contains("K3")]
data_k3.to_csv('car_K3.csv',encoding='EUC-KR',index=False)

# %%
data_k5=data_car_2[(data_car_2["모델"]).str.contains("K5")]
data_k5.to_csv('car_K5.csv',encoding='EUC-KR',index=False)

# %%
data_k7=data_car_2[(data_car_2["모델"]).str.contains("K7")]
data_k7.to_csv('car_K7.csv',encoding='EUC-KR',index=False)

# %%
data_g80=data_car_1[(data_car_1["모델"]).str.contains("G80")]
data_g80.to_csv('car_G80.csv',encoding='EUC-KR',index=False)

# %%
data_sonata=data_car_1[(data_car_1["모델"]).str.contains("쏘나타")]
data_sonata.to_csv('car_쏘나타.csv',encoding='EUC-KR',index=False)

# %%
data_avante=data_car_1[(data_car_1["모델"]).str.contains("아반떼")]
data_avante.to_csv('car_아반떼.csv',encoding='EUC-KR',index=False)

# %%
data_avante=data_car_2[(data_car_2["모델"]).str.contains("레이")]
data_avante.to_csv('car_레이.csv',encoding='EUC-KR',index=False)

# %%
data_re=data_car_2[(data_car_2["모델"]).str.contains("렉스턴")]
data_re.to_csv('car_렉스턴.csv',encoding='EUC-KR',index=False)

# %%
data_t=data_car_2[(data_car_2["모델"]).str.contains("티볼리")]
data_t.to_csv('car_티볼리.csv',encoding='EUC-KR',index=False)

# %%
data_sm5=data_car_1[(data_car_1["모델"]).str.contains("SM5")]
data_sm5.to_csv('car_SM5.csv',encoding='EUC-KR',index=False)

# %%
data_sm3=data_car_1[(data_car_1["모델"]).str.contains("SM3")]
data_sm3.to_csv('car_SM3.csv',encoding='EUC-KR',index=False)

# %%
data_sm6=data_car_1[(data_car_1["모델"]).str.contains("SM6")]
data_sm6.to_csv('car_SM6.csv',encoding='EUC-KR',index=False)

# %%
data_qm6=data_car_1[(data_car_1["모델"]).str.contains("QM6")]
data_qm6.to_csv('car_QM6.csv',encoding='EUC-KR',index=False)

# %%
data_qm3=data_car_1[(data_car_1["모델"]).str.contains("QM3")]
data_qm3.to_csv('car_QM3.csv',encoding='EUC-KR',index=False)

# %%
data_spark=data[(data["모델"]).str.contains("스파크")]
data_spark.to_csv('car_스파크.csv',encoding='EUC-KR',index=False)

# %%
data_spark=data[(data["모델"]).str.contains("말리부")]
data_spark.to_csv('car_말리부.csv',encoding='EUC-KR',index=False)

# %%
data_spark=data[(data["모델"]).str.contains("크루즈")]
data_spark.to_csv('car_크루즈.csv',encoding='EUC-KR',index=False)

# %%
data_spark=data[(data["모델"]).str.contains("다마스")]
data_spark.to_csv('car_다마스.csv',encoding='EUC-KR',index=False)

# %%
import os

path = "./car_dictionary/"
file_list = os.listdir(path)
file_list[:-1]
data_cars = pd.DataFrame()
for file in file_list[:-1] :
    data=pd.read_csv("./car_dictionary/"+file,encoding="EUC-KR")
    data_cars=pd.concat([data_cars,data])

# %%
data_cars.to_csv('car_종합.csv',encoding='EUC-KR',index=False)

# %%
file_list= os.listdir(path)
file_list
# Out:
# ['car_G80_수정.csv',
#  'car_K3.csv',
#  'car_K5.csv',
#  'car_K7.csv',
#  'car_K9.csv',
#  'car_QM3_수정.csv',
#  'car_QM6_수정.csv',
#  'car_SM3_수정.csv',
#  'car_SM5_수정.csv',
#  'car_SM6_수정.csv',
#  'car_다마스_수정.csv',
#  'car_라세티.csv',
#  'car_레이.csv',
#  'car_렉스턴_수정.csv',
#  'car_마티즈.csv',
#  'car_말리부_수정.csv',
#  'car_모닝.csv',
#  'car_모하비.csv',
#  'car_스토닉.csv',
#  'car_스파크_수정.csv',
#  'car_스포티지.csv',
#  'car_쏘렌토.csv',
#  'car_올란도.csv',
#  'car_카니발.csv',
#  'car_코란도_수정.csv',
#  'car_크루즈_수정.csv',
#  'car_티볼리_수정.csv',
#  'car_현대+제네시스 수정.csv',
#  'car_현대,기아_종합본.xlsx',
#  'desktop.ini',
#  '~$car_현대,기아_종합본.xlsx']

# %%
data_je=pd.read_csv('car_data_제네시스.csv',encoding="EUC-KR")
data_je=data

# %%
data_je
# Out:
#      제조사      모델          세부모델             등급    연식    출시일     차량가격 차종국가  \
# 0     현대     i20       1.4 가솔린       (08~11년)  2008  70.01      0만원   한국
# 1     현대     i20       1.4 가솔린       (12~14년)  2012  70.01      0만원   한국
# 2     현대  i30 PD     1.4 T-GDi            스타일  2017  18.01  1,890만원   한국
# 3     현대  i30 PD     1.4 T-GDi            스타일  2019   18.1  1,855만원   한국
# 4     현대  i30 PD     1.4 T-GDi       스타일 베스트핏  2017  18.01  2,025만원   한국
# ...   ..     ...           ...            ...   ...    ...      ...  ...
# 3788  현대     포터2  초장축 슈퍼캡 냉동탑차  PLUS 전동컴프(경제)  2020  70.01      0만원   한국
# 3789  현대     포터2  초장축 슈퍼캡 냉동탑차      PLUS 전동컴프  2020  70.01      0만원   한국
# 3790  현대     포터2  초장축 슈퍼캡 냉동탑차       SUP 전동컴프  2020  70.01      0만원   한국
# 3791  현대     포터2  초장축 슈퍼캡 냉동탑차            스타일  2020  70.01      0만원   한국
# 3792  현대     포터2  초장축 슈퍼캡 냉동탑차            스마트  2020  70.01      0만원   한국
#
#         복합연비      배기량  ... 복합연비(km/ℓ) 도심연비(km/ℓ) 고속연비(km/ℓ) CO2배출(g/km)  \
# ...

# %%
data_cars[().str.contains("제네시스 EQ9003.3 T-GDI AWD 럭셔리")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-55e5ec4d21d4> in <module>
# ----> 1 data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.contains("제네시스 EQ9003.3 T-GDI AWD 럭셔리")]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ...

# %%
import numpy as np

# %%
for data in data_je.iterrows() :
    print(data[1]["연식"][-5:-3])
#     print( data_cars[data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]==data[1]["모델명"]].index[0])
    if len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])])>0 :
        print(1)
    elif len(data_cars[data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]==data[1]["모델명"]]) :
        print(2)
    else :
        print(3)
# Out:
# 17
# 2
# 18
# 2
# 16
# 1
# 17
# 2
# 16
# 1
# 16
# 1
# 17
# 1
# 16
# 1
# 17
# 1
# 18
# 2
# 17
# 1
# 16
# 1
# 16
# 1
# 17
# 1
# 16
# 1
# 17
# 1
# 18
# 2
# 16
# 1
# 17
# 1
# 16
# 1
# 16
# 1
# 18
# 2
# 16
# 1
# 16
# 1
# 16
# 1
# 17
# 1
# 18
# 2
# 18
# 2
# 16
# 1
# 17
# 1
# 17
# 1
# 16
# 1
# 16
# 1
# 18
# 2
# 18
# 2
# 16
# 1
# 16
# 1
# 18
# 2
# 16
# 1
# 18
# 2
# 16
# 1
# 16
# 1
# 16
# 1
# 17
# 2
# 16
# 1
# 18
# 2
# 18
# 2
# 17
# 2
# 18
# 2
# 16
# 1
# 16
# 1
# 17
# 1
# 18
# 2
# 16
# 1
# 17
# 1
# 17
# 1
# 17
# 1
# 18
# 2
# 17
# 1
# 17
# 1
# 16
# 1
# 17
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 18
# 2
# 17
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 18
# 2
# 16
# 1
# 17
# 1
# 17
# 1
# 17
# 2
# 16
# 1
# 18
# 2
# 16
# 1
# 16
# 1
# 18
# 2
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 17
# 1
# 16
# 1
# 16
# 1
# 16
# 1
# 17
# 1
# 18
# 2
# 16
# 1
# 17
# 1
# 18
# 2
# 16
# 1
# 18
# 2
# 18
# 2
# 17
# 1
# 17
# 1
# 18
# 2
# 18
# 2
# 16
# 1
# 18
# 2
# ...

# %%
datadata= pd.DataFrame(np.array(data_list),columns=data_cars.columns)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-561-855c36cdd5f7> in <module>
# ----> 1 datadata= pd.DataFrame(np.array(data_list),columns=data_cars.columns)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# ...

# %%
 datadata.append(np.array(data_cars.iloc[car_index,:],ignore_index=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-557-df6bd7f3f8d1> in <module>
# ----> 1 datadata.append(np.array(data_cars.iloc[0,:],ignore_index=True))
#
# TypeError: 'ignore_index' is an invalid keyword argument for array()

# %%
data_set=pd.Data

# %%
datadata.append(data_list[0],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-540-64a4f68ede23> in <module>
# ----> 1 datadata.append(data_list[0],ignore_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7726             )
#    7727             if not self.columns.equals(combined_columns):
# -> 7728                 self = self.reindex(columns=combined_columns)
#    7729         elif isinstance(other, list):
#    7730             if not other:
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ...

# %%
datadata= pd.DataFrame(columns=col)
datadata.append(pd.concat([data_je.iloc[0,:],data_cars.iloc[0,:]]))
# Out:
#                            모델명   신차가격  중고차가격     차량번호            연식      주행거리  \
# 0  제네시스 EQ9003.3 T-GDI AWD 럭셔리  7,805  4,580  54마7456  17년03월(17년형)  32,626km
#
#     연료 변속기    연비  차종  배기량   색상  세금미납  압류   저당 전손이력 침수이력 용도이력 사용자변경  \
# 0  가솔린  오토  정보없음  대형  0cc  검정색  정보없음  없음  1 건   없음   없음   없음    1회
#
#                차체/일반              엔진/주요  \
# 0  87,374km / 8개월 남음  87,374km / 8개월 남음
#
#                                                   옵션  \
# 0  알루미늄휠/전동접이식미러/열선시트/파워핸들/가죽시트/메모리시트/하이패스/운전석에어백...
#
#                                                  url   제조사       모델     세부모델  \
# 0  https://www.kbchachacha.com/public/car/detail....  제네시스  G80(DH)  3.3 GDI
#
#     등급      연식    출시일     차량가격 차종국가    복합연비      배기량   최고출력    최대토크     에어백  \
# 0  럭셔리  2016.0  16.07  4,810만원   한국  10km/ℓ  3,342cc  282ps  35kg.m  운전석,커튼
#
#                                                 주행안전                       기타  \
# 0  ABS,전자식 트랙션 컨트롤,스테빌리티 컨트롤,전자식 제동력 분배 시스템,브레이크 ...  타이어 공기압 모니터링 시스템,ISOFIX
# ...

# %%
data11= pd.DataFrame(data_list,columns=col)
data11
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-511-f62598b6e710> in <module>
# ----> 1 data11= pd.DataFrame(data_list,columns=col)
#       2 data11
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                     if is_named_tuple(data[0]) and columns is None:
#     508                         columns = data[0]._fields
# --> 509                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     510                     columns = ensure_index(columns)
#     511
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     528         )
#     529     elif isinstance(data[0], ABCSeries):
# --> 530         return _list_of_series_to_arrays(
#     531             data, columns, coerce_float=coerce_float, dtype=dtype
# ...

# %%
col=['모델명', '신차가격', '중고차가격', '차량번호', '연식', '주행거리', '연료', '변속기', '연비', '차종',
        '배기량', '색상', '세금미납', '압류', '저당', '전손이력', '침수이력', '용도이력', '사용자변경',
        '차체/일반', '엔진/주요', '옵션', 'url','제조사', '모델', '세부모델', '등급', '연식', '출시일', '차량가격', '차종국가', '복합연비', '배기량',
        '최고출력', '최대토크', '에어백', '주행안전', '기타', '헤드램프', '리어램프', '사이드미러', '기타.1',
        '시트배열', '시트재질', '운전석', '동승석', '뒷좌석', '룸미러', '기타.2', '에어컨', '스티어링휠',
        '주차보조시스템', '스마트키', '크루즈컨트롤', '전자식파킹브레이크', '헤드업 디스플레이', '스타트스톱', '기타.3',
        '스피커', '블루투스', '단자', '네비게이션', '기타.4', '출시가격', '엔진형식', '실린더수', '배기량(cc)',
        '최고출력(ps/rpm)', '최대토크(kg·m/rpm)', '0→100km/h(초)', '최고속도(km/h)', '구동방식',
        '브레이크(전/후)', '서스펜션(전/후)', '스티어링', '타이어', '휠', '차체(길이x너비x높이mm)',
        '윤거(전x후mm)', '측간거리(mm)', '최저지상고(mm)', '최소회전반경(ft)', '연료', '복합연비(km/ℓ)',
        '도심연비(km/ℓ)', '고속연비(km/ℓ)', 'CO2배출(g/km)', '연료탱크(ℓ)', '기본', '파워트레인',
        '승차정원', '공차중량(kg)', '적재용량(kg)']

# %%
data_cars["연식"].astype("str").str[2:4]+data_cars[data_cars["제조사"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-357-25924f13e98a> in <module>
# ----> 1 data_cars["연식"].astype("str").str[2:4]+data_cars[data_cars["제조사"]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
data_je
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-365-20f6616cabd8> in <module>
# ----> 1 data_je[1]
#
# ...

# %%
==data[1][4][0:2]+data[1]["모델명"]
# Out:
# 0       16
# 1       18
# 2       19
# 3       16
# 4       18
#         ..
# 3834     n
# 3835     n
# 3836     n
# 3837     n
# 3838     n
# Name: 연식, Length: 4576, dtype: object

# %%
data_cars=pd.read_csv("차량제원수정완.csv",encoding="EUC-KR")
data_je=pd.read_csv("data_cars_크롤링.csv",encoding="EUC-KR")
# data_je=pd.read_csv("car_data_나머지3 (1).csv",encoding="EUC-KR")

# %%
(data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()
# Out:
# 0            제네시스 G80(DH) 3.3 GDI 럭셔리
# 1            제네시스 G80(DH) 3.3 GDI 럭셔리
# 2            제네시스 G80(DH) 3.3 GDI 럭셔리
# 3       제네시스 G80(DH) 3.3 GDI 프리미엄 럭셔리
# 4       제네시스 G80(DH) 3.3 GDI 프리미엄 럭셔리
#                     ...
# 2346        한국GM 더 넥스트 스파크 LTZ C-TECH
# 2347        한국GM 더 넥스트 스파크 LTZ C-TECH
# 2348        한국GM 더 넥스트 스파크 LTZ C-TECH
# 2349              한국GM 쉐보레 올란도 LT 고급형
# 2350        한국GM 라세티 프리미어 1.6 CDX 고급형
# Length: 2351, dtype: object

# %%
data_je=data_je.iloc[10000:,:]

# %%
data_je=pd.read_csv("car_data_제네시스나머지.csv",encoding="EUC-KR")
data_cars=pd.read_csv("차량제원_기본전처리_수정중.csv",encoding="EUC-KR")

# %%
for i in data_cars.columns[15:]:
    del data_cars[i]

# %%
data_cars.columns
# Out:
# Index(['제조사', '모델', '세부모델', '등급', '연식', '차량가격', '복합연비', '배기량', '최고출력', '최대토크',
#        '출시가격', '구동방식', '승차정원', '휠_1', '타이어_수정', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33'],
#       dtype='object')

# %%
import tqdm

# %%
c = 0
for data in data_je.iterrows() :
    
#     print(data[1]["연식"][-5:-3])
#     print( data_cars[data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]==data[1]["모델명"]].index[0])
    if len(data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])])>0 :
        pass
    elif len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]])>0:
        pass
    elif len(data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])])>0 :
        pass
    elif len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]])>0 :
        pass
    elif len(data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])])>0 :
        pass
    elif len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"]).str.strip()==data[1]["모델명"]])>0 :
        pass
    else :
        c += 1
        print(data[1][0],data[0])
print(c)
# Out:
# 제네시스 G80(DH)3.3 GDI 럭셔리 스페셜 55
# 제네시스 G80(DH)3.3 GDI 럭셔리 스페셜 88
# 2

# %%
col = ['모델명', '신차가격', '중고차가격', '차량번호', '연식', '주행거리', '연료', '변속기', '연비', '차종',
       '배기량', '색상', '세금미납', '압류', '저당', '전손이력', '침수이력', '용도이력', '사용자변경',
       '차체/일반', '엔진/주요', '옵션', 'url','제조사', '모델', '세부모델', '등급', '연식', '차량가격', '복합연비', '배기량', '최고출력', '최대토크',
       '출시가격', '구동방식', '승차정원', '휠_1', '타이어_수정']

# %%
data_cars.columns
# Out:
# Index(['제조사', '모델', '세부모델', '등급', '연식', '차량가격', '복합연비', '배기량', '최고출력', '최대토크',
#        '출시가격', '구동방식', '승차정원', '휠_1', '타이어_수정'],
#       dtype='object')

# %%
datadata= pd.DataFrame(columns=data_cars.columns)
data_list = []
c=0
for data in data_je.iterrows() :
    car_index = 0
    #자동차제원 데이터의 자동차이름과 크롤링데이터의 자동차이름을 일치한 데이터를
    #제조사 모델 세부모델 등급 연식 또는 제조사 모델 세부모델 등급에 맞게 찾아주는 역활을 함 
    if len(data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])])>0 :
        car_index=data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])].index[0]
    elif len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]])>0 :
        car_index=data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+" "+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]].index[0]
    elif len(data_cars[data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]==data[1]["모델명"]]) >0 :
        car_index=data_cars[data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]==data[1]["모델명"]].index[0]
    elif len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]])>0:
        car_index=data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"] +" "+data_cars["등급"]).str.strip()==data[1]["모델명"]].index[0]
    elif len(data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])])>0 :
        car_index=data_cars[((data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"]).str.strip()==data[1]["모델명"]) & (data_cars["연식"].astype("str").str[2:4]==data[1]["연식"][-5:-3])].index[0]
    elif len(data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"]).str.strip()==data[1]["모델명"]])>0 :
        car_index=data_cars[(data_cars["제조사"]+" "+data_cars["모델"]+""+data_cars["세부모델"]).str.strip()==data[1]["모델명"]].index[0]
    #    
    data_list.append(pd.Series(pd.concat([data[1],data_cars.iloc[car_index,:]],ignore_index=True)))
# Out:
# 제네시스 G80(DH)3.3 GDI 럭셔리 스페셜 16602
# 제네시스 G80(DH)3.3 GDI 럭셔리 스페셜 16635

# %%
data_je.shape
# Out:
# (17245, 23)

# %%
data22.columns=col
data22
# Out:
#                               모델명   신차가격  중고차가격      차량번호            연식  \
# 0         한국GM 더 뉴 스파크Premier 기본형  1,448  1,030  229저5202  19년12월(20년형)
# 1         한국GM 더 뉴 스파크Premier 기본형  1,448    990  128다4221  19년12월(19년형)
# 2         한국GM 더 뉴 스파크Premier 기본형  1,448    970   17저3149  18년09월(19년형)
# 3         한국GM 더 뉴 스파크Premier 기본형  1,448    999  153주4382  19년11월(20년형)
# 4         한국GM 더 뉴 스파크Premier 기본형  1,448    990   13노6703  18년10월(19년형)
# ...                           ...    ...    ...       ...           ...
# 17238  제네시스 G702.0T Sport Package  4,398  2,990  223부5955  19년06월(19년형)
# 17239        제네시스 G702.0T Supreme  3,956  3,090   55다5211  18년02월(18년형)
# 17240        제네시스 G702.0T Supreme  3,956  3,130   18수6749  18년04월(18년형)
# 17241       제네시스 G702.0T Advanced  3,848  2,930  300고3004  19년03월(19년형)
# 17242       제네시스 G702.0T Advanced  3,701  2,790   33부8382  18년10월(18년형)
#
#            주행거리   연료  변속기      연비  차종  ...  차량가격 복합연비   배기량 최고출력 최대토크  출시가격  \
# ...

# %%
data22=pd.DataFrame(np.array(data_list))

# %%
data=data22.iloc[:,:38]

# %%
data.columns = col

# %%
data.to_csv("car_learning_data_new3.csv",encoding="EUC-KR",index=False)
